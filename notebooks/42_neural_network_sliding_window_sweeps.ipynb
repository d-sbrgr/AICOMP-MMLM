# %% [markdown]
# # Neural Network Hyperparameter Sweeps - Sliding Window Dataloader
#
# This notebook runs W&B sweeps to find optimal hyperparameters for neural network models.

# %%
# Only required on GPU Hub
# %pip install dotenv wandb xgboost catboost lightning

# %%
import sys

sys.path.append("..")

import dotenv
import wandb

from src.api.run.neural_network import sweep_neural_network
from src.api.sweep import wandb_sweep
from src.models.neural_network.submission import create_submission
# Out:
# c:\Users\kybur\Repos\HSLU\aicomp\code\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# c:\Users\kybur\Repos\HSLU\aicomp\code\.venv\Lib\site-packages\pydantic\_internal\_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(

# %%
dotenv.load_dotenv()
wandb.login()
# Out:
# wandb: Currently logged in as: v8-luky (aicomp-mmlm) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ## Sweep 1: MSE Loss

# %%
max_runs = 100
sweep_config = {
    "name": "Neural Network (Sliding Window)",
    "method": "bayes",
    "metric": {"name": "val_brier", "goal": "minimize"},
    "parameters": {
        "neural_network_config": {
            "parameters": {
                "hidden_layers": {
                    "values": [
                        [64, 32],
                        [128, 64],
                        [128, 64, 32],
                        [256, 128],
                        [256, 128, 64],
                        [256, 128, 64, 32],
                        [512, 256],
                        [512, 256, 128],
                        [512, 256, 128, 64],
                        [512, 256, 128, 64, 32],
                        [512, 1024, 512, 256, 128],
                        [512, 1024, 512, 256, 128, 64],
                        [512, 1024, 512, 256, 128, 64, 32],
                    ]
                },
                "activation": {"values": ["relu", "leaky_relu", "gelu", "elu"]},
                "dropout": {"distribution": "uniform", "min": 0.0, "max": 0.5},
                "batch_norm": {"value": True},
                "learning_rate": {"distribution": "log_uniform_values", "min": 0.0001, "max": 0.01},
                "optimizer": {"value": "adamw"},
                "weight_decay": {"distribution": "uniform", "min": 0.0, "max": 0.1},
                "early_stopping_patience": {"value": 10},
                "seed": {"value": 42},
                "loss_function": {"value": "mse"},
                "scheduler": {"values": [None, "step", "cosine", "exponential", "reduce_on_plateau"]},
                "scheduler_step_size": {"values": [10, 15, 20, 25, 30]},
                "scheduler_gamma": {"distribution": "log_uniform_values", "min": 0.7, "max": 0.99},
                "scheduler_patience": {"values": [3, 5, 7]},
                "num_workers": {"value": 16},
            },
        },
        "run_config": {
            "parameters": {
                "valid_season": {"value": 0},
                "start_season": {"value": 0},
                "num_features": {"distribution": "int_uniform", "min": 10, "max": 100},
                "data_loader": {"value": "sliding_window_average"},
            },
        },
    },
}

# %%
wandb_sweep(sweep_config, sweep_neural_network, run_count=max_runs, project="neural-network")

# %% [markdown]
# ### Create Submission from Best Model (Loss: MSE)

# %%
create_submission(season=2025, artifact_name="v867gled:v0", submission_affix="sliding_window")
# Out:
# Config: {'config': "NeuralNetworkHyperparamConfig(hidden_layers=[64, 32], activation='elu', dropout=0.4117068571128791, batch_norm=True, input_dropout=0.0, learning_rate=0.0002832238432182205, batch_size=512, max_epochs=200, optimizer='adamw', weight_decay=0.09432155823149914, momentum=0.9, scheduler='step', scheduler_step_size=20, scheduler_gamma=0.7935242471280746, scheduler_patience=7, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.0001, loss_function='mse', validation_split=0.1, weight_init='xavier_uniform', gradient_clip_val=None, accumulate_grad_batches=1, num_workers=16, seed=42)", 'input_dim': 81, 'run_config': {'data_loader': 'sliding_window_average', 'num_features': 84, 'start_season': 0, 'valid_season': 0}, 'neural_network_config': {'seed': 42, 'dropout': 0.4117068571128791, 'optimizer': 'adamw', 'scheduler': 'step', 'activation': 'elu', 'batch_norm': True, 'num_workers': 16, 'weight_decay': 0.09432155823149914, 'hidden_layers': [64, 32], 'learning_rate': 0.0002832238432182205, 'loss_function': 'mse', 'scheduler_gamma': 0.7935242471280746, 'scheduler_patience': 7, 'scheduler_step_size': 20, 'early_stopping_patience': 10}}
# Run Config: RunConfig(num_features=84, valid_season=0, start_season=0, data_loader='sliding_window_average', data_loader_config=None)
# Hyperparameters: NeuralNetworkHyperparamConfig(hidden_layers=[64, 32], activation='elu', dropout=0.4117068571128791, batch_norm=True, input_dropout=0.0, learning_rate=0.0002832238432182205, batch_size=512, max_epochs=200, optimizer='adamw', weight_decay=0.09432155823149914, momentum=0.9, scheduler='step', scheduler_step_size=20, scheduler_gamma=0.7935242471280746, scheduler_patience=7, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.0001, loss_function='mse', validation_split=0.1, weight_init='xavier_uniform', gradient_clip_val=None, accumulate_grad_batches=1, num_workers=16, seed=42)
# Seed set to 42
# wandb:   1 of 1 files downloaded.
# Created submission at: C:\Users\kybur\Repos\HSLU\aicomp\code\submissions\submission_neural_network_sliding_window_2025.csv

# %% [markdown]
# ## Sweep 2: BCE Loss

# %%
max_runs = 100
sweep_config = {
    "name": "Neural Network (Sliding Window, BCE)",
    "method": "bayes",
    "metric": {"name": "val_brier", "goal": "minimize"},
    "parameters": {
        "neural_network_config": {
            "parameters": {
                "hidden_layers": {
                    "values": [
                        [64, 32],
                        [128, 64],
                        [128, 64, 32],
                        [256, 128],
                        [256, 128, 64],
                        [256, 128, 64, 32],
                        [512, 256],
                        [512, 256, 128],
                        [512, 256, 128, 64],
                        [512, 256, 128, 64, 32],
                        [512, 1024, 512, 256, 128],
                        [512, 1024, 512, 256, 128, 64],
                        [512, 1024, 512, 256, 128, 64, 32],
                    ]
                },
                "activation": {"values": ["relu", "leaky_relu", "gelu", "elu"]},
                "dropout": {"distribution": "uniform", "min": 0.0, "max": 0.5},
                "batch_norm": {"value": True},
                "learning_rate": {"distribution": "log_uniform_values", "min": 0.0001, "max": 0.01},
                "optimizer": {"value": "adamw"},
                "weight_decay": {"distribution": "uniform", "min": 0.0, "max": 0.1},
                "early_stopping_patience": {"value": 5},
                "seed": {"value": 42},
                "loss_function": {"value": "bce"},
                "scheduler": {"values": [None, "step", "cosine", "exponential", "reduce_on_plateau"]},
                "scheduler_step_size": {"values": [10, 15, 20, 25, 30]},
                "scheduler_gamma": {"distribution": "log_uniform_values", "min": 0.7, "max": 0.99},
                "scheduler_patience": {"values": [3, 5, 7]},
                "num_workers": {"value": 16},
            },
        },
        "run_config": {
            "parameters": {
                "valid_season": {"value": 0},
                "start_season": {"value": 0},
                "num_features": {"distribution": "int_uniform", "min": 10, "max": 100},
                "data_loader": {"value": "sliding_window_average"},
            },
        },
    },
}

# %%
wandb_sweep(sweep_config, sweep_neural_network, run_count=max_runs, project="neural-network")

# %% [markdown]
# ### Create Submission from Best Model (Loss: BCE)

# %%
create_submission(season=2025, artifact_name="5f4pda6o:v0", submission_affix="sliding_window_bce")
# Out:
# Config: {'config': "NeuralNetworkHyperparamConfig(hidden_layers=[128, 64, 32], activation='gelu', dropout=0.4802388705547117, batch_norm=True, input_dropout=0.0, learning_rate=0.0031183640002932105, batch_size=512, max_epochs=200, optimizer='adamw', weight_decay=0.06045248574253619, momentum=0.9, scheduler='exponential', scheduler_step_size=10, scheduler_gamma=0.8623433468922149, scheduler_patience=5, early_stopping=True, early_stopping_patience=5, early_stopping_min_delta=0.0001, loss_function='bce', validation_split=0.1, weight_init='xavier_uniform', gradient_clip_val=None, accumulate_grad_batches=1, num_workers=16, seed=42)", 'input_dim': 81, 'run_config': {'data_loader': 'sliding_window_average', 'num_features': 97, 'start_season': 0, 'valid_season': 0}, 'neural_network_config': {'seed': 42, 'dropout': 0.4802388705547117, 'optimizer': 'adamw', 'scheduler': 'exponential', 'activation': 'gelu', 'batch_norm': True, 'num_workers': 16, 'weight_decay': 0.06045248574253619, 'hidden_layers': [128, 64, 32], 'learning_rate': 0.0031183640002932105, 'loss_function': 'bce', 'scheduler_gamma': 0.8623433468922149, 'scheduler_patience': 5, 'scheduler_step_size': 10, 'early_stopping_patience': 5}}
# Run Config: RunConfig(num_features=97, valid_season=0, start_season=0, data_loader='sliding_window_average', data_loader_config=None)
# Hyperparameters: NeuralNetworkHyperparamConfig(hidden_layers=[128, 64, 32], activation='gelu', dropout=0.4802388705547117, batch_norm=True, input_dropout=0.0, learning_rate=0.0031183640002932105, batch_size=512, max_epochs=200, optimizer='adamw', weight_decay=0.06045248574253619, momentum=0.9, scheduler='exponential', scheduler_step_size=10, scheduler_gamma=0.8623433468922149, scheduler_patience=5, early_stopping=True, early_stopping_patience=5, early_stopping_min_delta=0.0001, loss_function='bce', validation_split=0.1, weight_init='xavier_uniform', gradient_clip_val=None, accumulate_grad_batches=1, num_workers=16, seed=42)
# Seed set to 42
# wandb:   1 of 1 files downloaded.
# Created submission at: C:\Users\kybur\Repos\HSLU\aicomp\code\submissions\submission_neural_network_sliding_window_bce_2025.csv

# %% [markdown]
# ## Sweep 3: Default Features (num_features=0)

# %%
max_runs = 100
sweep_config = {
    "name": "Neural Network (Sliding Window, Default Features)",
    "method": "bayes",
    "metric": {"name": "val_brier", "goal": "minimize"},
    "parameters": {
        "neural_network_config": {
            "parameters": {
                "hidden_layers": {
                    "values": [
                        [64, 32],
                        [128, 64],
                        [128, 64, 32],
                        [256, 128],
                        [256, 128, 64],
                        [256, 128, 64, 32],
                        [512, 256],
                        [512, 256, 128],
                        [512, 256, 128, 64],
                        [512, 256, 128, 64, 32],
                        [512, 1024, 512, 256, 128],
                        [512, 1024, 512, 256, 128, 64],
                        [512, 1024, 512, 256, 128, 64, 32],
                    ]
                },
                "activation": {"values": ["relu", "leaky_relu", "gelu", "elu"]},
                "dropout": {"distribution": "uniform", "min": 0.0, "max": 0.5},
                "batch_norm": {"value": True},
                "learning_rate": {"distribution": "log_uniform_values", "min": 0.0001, "max": 0.01},
                "optimizer": {"value": "adamw"},
                "weight_decay": {"distribution": "uniform", "min": 0.0, "max": 0.1},
                "early_stopping_patience": {"value": 10},
                "seed": {"value": 42},
                "loss_function": {"value": "mse"},
                "scheduler": {"values": [None, "step", "cosine", "exponential", "reduce_on_plateau"]},
                "scheduler_step_size": {"values": [10, 15, 20, 25, 30]},
                "scheduler_gamma": {"distribution": "log_uniform_values", "min": 0.7, "max": 0.99},
                "scheduler_patience": {"values": [3, 5, 7]},
                "num_workers": {"value": 16},
            },
        },
        "run_config": {
            "parameters": {
                "valid_season": {"value": 0},
                "start_season": {"value": 0},
                "num_features": {"value": 0},
                "data_loader": {"value": "sliding_window_average"},
            },
        },
    },
}

# %%
wandb_sweep(sweep_config, sweep_neural_network, run_count=max_runs, project="neural-network")

# %% [markdown]
# ### Create Submission from Best Model (Default Features)

# %%
create_submission(season=2025, artifact_name="gtre4q4w:v1", submission_affix="sliding_window_default_features")
# Out:
# Config: {'config': "NeuralNetworkHyperparamConfig(hidden_layers=[256, 128, 64], activation='gelu', dropout=0.432895745069677, batch_norm=True, input_dropout=0.0, learning_rate=0.004489711683253849, batch_size=512, max_epochs=200, optimizer='adamw', weight_decay=0.09001095376719459, momentum=0.9, scheduler='exponential', scheduler_step_size=15, scheduler_gamma=0.7415372395940799, scheduler_patience=3, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.0001, loss_function='mse', validation_split=0.1, weight_init='xavier_uniform', gradient_clip_val=None, accumulate_grad_batches=1, num_workers=16, seed=42)", 'input_dim': 26, 'run_config': {'data_loader': 'sliding_window_average', 'num_features': 0, 'start_season': 0, 'valid_season': 0}, 'neural_network_config': {'seed': 42, 'dropout': 0.432895745069677, 'optimizer': 'adamw', 'scheduler': 'exponential', 'activation': 'gelu', 'batch_norm': True, 'num_workers': 16, 'weight_decay': 0.09001095376719459, 'hidden_layers': [256, 128, 64], 'learning_rate': 0.004489711683253849, 'loss_function': 'mse', 'scheduler_gamma': 0.7415372395940799, 'scheduler_patience': 3, 'scheduler_step_size': 15, 'early_stopping_patience': 10}}
# Run Config: RunConfig(num_features=0, valid_season=0, start_season=0, data_loader='sliding_window_average', data_loader_config=None)
# Hyperparameters: NeuralNetworkHyperparamConfig(hidden_layers=[256, 128, 64], activation='gelu', dropout=0.432895745069677, batch_norm=True, input_dropout=0.0, learning_rate=0.004489711683253849, batch_size=512, max_epochs=200, optimizer='adamw', weight_decay=0.09001095376719459, momentum=0.9, scheduler='exponential', scheduler_step_size=15, scheduler_gamma=0.7415372395940799, scheduler_patience=3, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.0001, loss_function='mse', validation_split=0.1, weight_init='xavier_uniform', gradient_clip_val=None, accumulate_grad_batches=1, num_workers=16, seed=42)
# Seed set to 42
# wandb:   1 of 1 files downloaded.
# Created submission at: C:\Users\kybur\Repos\HSLU\aicomp\code\submissions\submission_neural_network_sliding_window_default_features_2025.csv

# %% [markdown]
# ## Sweep 4: BCE with Entropy Loss

# %%
max_runs = 100
sweep_config = {
    "name": "Neural Network (Sliding Window, BCEwEntropy)",
    "method": "bayes",
    "metric": {"name": "val_brier", "goal": "minimize"},
    "parameters": {
        "neural_network_config": {
            "parameters": {
                "hidden_layers": {
                    "values": [
                        [64, 32],
                        [128, 64],
                        [128, 64, 32],
                        [256, 128],
                        [256, 128, 64],
                        [256, 128, 64, 32],
                        [512, 256],
                        [512, 256, 128],
                        [512, 256, 128, 64],
                        [512, 256, 128, 64, 32],
                        [512, 1024, 512, 256, 128],
                        [512, 1024, 512, 256, 128, 64],
                        [512, 1024, 512, 256, 128, 64, 32],
                    ]
                },
                "activation": {"values": ["relu", "leaky_relu", "gelu", "elu"]},
                "dropout": {"distribution": "uniform", "min": 0.0, "max": 0.5},
                "batch_norm": {"value": True},
                "learning_rate": {"distribution": "log_uniform_values", "min": 0.0001, "max": 0.01},
                "optimizer": {"value": "adamw"},
                "weight_decay": {"distribution": "uniform", "min": 0.0, "max": 0.1},
                "early_stopping_patience": {"value": 10},
                "seed": {"value": 42},
                "loss_function": {"value": "bce_entropy"},
                "scheduler": {"values": [None, "step", "cosine", "exponential", "reduce_on_plateau"]},
                "scheduler_step_size": {"values": [10, 15, 20, 25, 30]},
                "scheduler_gamma": {"distribution": "log_uniform_values", "min": 0.7, "max": 0.99},
                "scheduler_patience": {"values": [3, 5, 7]},
                "num_workers": {"value": 16},
            },
        },
        "run_config": {
            "parameters": {
                "valid_season": {"value": 0},
                "start_season": {"value": 0},
                "num_features": {"distribution": "int_uniform", "min": 10, "max": 100},
                "data_loader": {"value": "sliding_window_average"},
            },
        },
    },
}

# %%
wandb_sweep(sweep_config, sweep_neural_network, run_count=max_runs, project="neural-network")

# %% [markdown]
# ### Create Submission from Best Model (Loss: BCE with Entropy)

# %%
create_submission(season=2025, artifact_name="g112q4n9:v5", submission_affix="sliding_window_bce_entropy")
# Out:
# Config: {'config': "NeuralNetworkHyperparamConfig(hidden_layers=[128, 64], activation='elu', dropout=0.461244375873225, batch_norm=True, input_dropout=0.0, learning_rate=0.0001307468806289503, batch_size=512, max_epochs=200, optimizer='adamw', weight_decay=0.040574815720774315, momentum=0.9, scheduler='exponential', scheduler_step_size=20, scheduler_gamma=0.7932475192096688, scheduler_patience=3, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.0001, loss_function='bce_entropy', validation_split=0.1, weight_init='xavier_uniform', gradient_clip_val=None, accumulate_grad_batches=1, num_workers=16, seed=42)", 'input_dim': 81, 'run_config': {'data_loader': 'sliding_window_average', 'num_features': 98, 'start_season': 0, 'valid_season': 0}, 'neural_network_config': {'seed': 42, 'dropout': 0.461244375873225, 'optimizer': 'adamw', 'scheduler': 'exponential', 'activation': 'elu', 'batch_norm': True, 'num_workers': 16, 'weight_decay': 0.040574815720774315, 'hidden_layers': [128, 64], 'learning_rate': 0.0001307468806289503, 'loss_function': 'bce_entropy', 'scheduler_gamma': 0.7932475192096688, 'scheduler_patience': 3, 'scheduler_step_size': 20, 'early_stopping_patience': 10}}
# Run Config: RunConfig(num_features=98, valid_season=0, start_season=0, data_loader='sliding_window_average', data_loader_config=None)
# Hyperparameters: NeuralNetworkHyperparamConfig(hidden_layers=[128, 64], activation='elu', dropout=0.461244375873225, batch_norm=True, input_dropout=0.0, learning_rate=0.0001307468806289503, batch_size=512, max_epochs=200, optimizer='adamw', weight_decay=0.040574815720774315, momentum=0.9, scheduler='exponential', scheduler_step_size=20, scheduler_gamma=0.7932475192096688, scheduler_patience=3, early_stopping=True, early_stopping_patience=10, early_stopping_min_delta=0.0001, loss_function='bce_entropy', validation_split=0.1, weight_init='xavier_uniform', gradient_clip_val=None, accumulate_grad_batches=1, num_workers=16, seed=42)
# Seed set to 42
# wandb:   1 of 1 files downloaded.
# Created submission at: C:\Users\kybur\Repos\HSLU\aicomp\code\submissions\submission_neural_network_sliding_window_bce_entropy_2025.csv
